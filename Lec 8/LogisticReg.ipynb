# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("insurance_data.csv")
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
# %matplotlib inline
plt.xlabel("age")
plt.ylabel("brought/not")
plt.scatter(df[["age"]],df[["bought_insurance"]],color="red",marker="+")

# %%
X=df[["age"]]
y=df[["bought_insurance"]]
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
X_test
# Out:
#     age
# 18   19
# 15   55
# 3    52
# 11   28
# 8    62
# 12   27

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(X_train, y_train)
# Out:
# C:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1229: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([0, 1, 1, 0, 1, 0], dtype=int64)

# %%
model.score(X_test,y_test)
# Out:
# 0.8333333333333334

# %%
model.predict_proba(X_test)
# Out:
# array([[0.91844701, 0.08155299],
#        [0.05355227, 0.94644773],
#        [0.08084407, 0.91915593],
#        [0.74989624, 0.25010376],
#        [0.01981413, 0.98018587],
#        [0.77645055, 0.22354945]])

# %%
model.coef_
# Out:
# array([[0.14704135]])

# %%
model.intercept_
# Out:
# array([-5.2152169])
